# %%
import pandas as pd

# %%
df = pd.read_sql("select * from country where continent = 'Asia' order by indep_year desc", 'postgresql://netology:NetoSQL2019@84.201.153.170:19001/world-db')
df.head(55)

# %%
df = pd.read_sql(
"""
select 
  *
from
  city c
inner join
  country ct
on
  c.country_code = ct.code
where
    continent = 'Asia' AND
    c.population > 1500000
""", 

'postgresql://netology:NetoSQL2019@84.201.153.170:19001/world-db')
df.head(55)
# Out:
#       id                     name country_code              district  \
# 0      1                    Kabul          AFG                 Kabol
# 1    144                     Baku          AZE                  Baki
# 2    150                    Dhaka          BGD                 Dhaka
# 3    765                   Quezon          PHL  National Capital Reg
# 4    766                   Manila          PHL  National Capital Reg
# 5    936  Kowloon and New Kowloon          HKG  Kowloon and New Kowl
# 6    939                  Jakarta          IDN          Jakarta Raya
# 7    940                 Surabaya          IDN             East Java
# 8    941                  Bandung          IDN             West Java
# 9    942                    Medan          IDN        Sumatera Utara
# 10  1024          Mumbai (Bombay)          IND           Maharashtra
# 11  1025                    Delhi          IND                 Delhi
# 12  1026       Calcutta [Kolkata]          IND          West Bengali
# ...

# %%
df_country = pd.read_sql(
"""
select 
  *
from
  country
""", 
'postgresql://netology:NetoSQL2019@84.201.153.170:19001/world-db')
df_country.head()

# %%
df_city = pd.read_sql(
"""
select 
  *
from
  city
""", 
'postgresql://netology:NetoSQL2019@84.201.153.170:19001/world-db')
df_city.head()
# Out:
#    id            name country_code       district  population
# 0   1           Kabul          AFG          Kabol     1780000
# 1   2        Qandahar          AFG       Qandahar      237500
# 2   3           Herat          AFG          Herat      186800
# 3   4  Mazar-e-Sharif          AFG          Balkh      127800
# 4   5       Amsterdam          NLD  Noord-Holland      731200

# %%
df_merged = df_city.merge(
    df_country,
    left_on='country_code', 
    right_on='code',
    how='inner'
)
df_merged.head()
