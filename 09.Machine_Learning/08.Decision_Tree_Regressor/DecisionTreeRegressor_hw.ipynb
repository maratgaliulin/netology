# %%
import numpy as np
import pandas as pd
from sklearn.datasets import fetch_california_housing as fch

import seaborn as sns 
from matplotlib import pyplot as plt
 
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score as r2
from sklearn.metrics import mean_squared_error as mse

from sklearn.cluster import KMeans


pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
california_housing = fch(as_frame=True).frame

# %%
# Функции нормализации значений по минимаксу и для z-масштабирования (реализовал как функции, хотя можно использовать StandardScaler)

def normalize (dt, strg, dt_min, dt_max):
  return (dt[strg] - dt_min) / (dt_max - dt_min)
  
def z_scale(dt, strg, dt_mean, dt_stdev):
  return (dt[strg] - dt_mean) / dt_stdev

# %%
# Дополнительные признаки, полученные в результате эффектов взаимодействия (новые признаки из имеющихся данных):

california_housing['Bedrooms_per_Room'] = california_housing['AveBedrms'] / california_housing['AveRooms']  # - количество спален на каждую комнату
california_housing['Total_Avg_Rooms'] = california_housing['AveRooms'] + california_housing['AveBedrms'] # - сумма всех комнат (спальни + другие комнаты)
california_housing['Population_per_Room'] = california_housing['Population'] / california_housing['Total_Avg_Rooms'] # - среднее кол-во человек на каждую комнату
california_housing['MedInc_norm'] = california_housing.apply(normalize, strg='MedInc', dt_min = california_housing['MedInc'].min(),  dt_max = california_housing['MedInc'].max(), axis=1)
km = KMeans(n_clusters = 25)
cluster = km.fit_predict(california_housing[['Latitude', 'Longitude']])
california_housing['Region_cluster'] = cluster
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
housing_names = ['MedInc', 'HouseAge','AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude', 'Bedrooms_per_Room', 'Total_Avg_Rooms', 'Population_per_Room', 'MedInc_norm', 'Region_cluster'] # - список столбцов

# %%
california_housing.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal  Bedrooms_per_Room  Total_Avg_Rooms  \
# 0    -122.23        4.526           0.146591         8.007937
# 1    -122.22        3.585           0.155797         7.210018
# 2    -122.24        3.521           0.129516         9.361582
# 3    -122.25        3.413           0.184458         6.890411
# 4    -122.25        3.422           0.172096         7.362934
#
#    Population_per_Room  MedInc_norm  Region_cluster
# 0            40.210109     0.539668               4
# 1           333.008897     0.538027               4
# 2            52.982498     0.466028               4
# 3            80.982107     0.354699               4
# 4            76.735711     0.230776               4

# %%
X_data = california_housing[housing_names]
y_data = california_housing['MedHouseVal']

# %%
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.2, random_state=20 )
housing_model = LinearRegression()
housing_model.fit(X_train, y_train)

predicted_data = housing_model.predict(X_test)
print('predicted_data: ', predicted_data)

predicted_data_train = housing_model.predict(X_train)
print('predicted_data_train: ', predicted_data_train)

print(housing_model.score(X_train, y_train))
print(housing_model.score(X_test, y_test))

mse_data = mse(y_test, predicted_data)
print(mse_data)
# print(np.sqrt(mse_data))

mse_data_train = mse(y_train, predicted_data_train)
print(mse_data_train)
# Out:
# predicted_data:  [1.57868605 2.99957163 1.77108504 ... 1.75578463 2.82586997 1.17070104]
# predicted_data_train:  [1.74155561 1.89681747 2.34376916 ... 2.26669745 3.03745231 2.55776053]
# 0.6122979778273303
# 0.6231701081065317
# 0.5256547210671059
# 0.5100997138592676

# %%
housing_decision_tree = DecisionTreeRegressor(random_state=20)
housing_decision_tree.fit(X_train, y_train)

housing_dt_predictions = housing_decision_tree.predict(X_test)
tree_mse = mse(y_test, housing_dt_predictions)
tree_rmse = np.sqrt(tree_mse)

train_score = housing_decision_tree.score(X_train, y_train)
test_score = housing_decision_tree.score(X_test, y_test)

# %%
print('Предсказанные значения: ', housing_dt_predictions)
print('Средняя квадратическая ошибка: ', tree_mse)
print('Корень средней квадратической ошибки: ', tree_rmse)
print('Точность модели на тренировочной выборке: ', train_score)
print('Точность модели на тестовой выборке: ', test_score)
# Out:
# Предсказанные значения:  [1.293 2.636 1.555 ... 1.234 2.086 0.823]
# Средняя квадратическая ошибка:  0.5193198605811288
# Корень средней квадратической ошибки:  0.7206385089496181
# Точность модели на тренировочной выборке:  1.0
# Точность модели на тестовой выборке:  0.6277114252419412

# %% [markdown]
# Как видно из результатов выше, произошло переобучение модели - точность модели на тренировочных данных оказалась равной 100%, а на тестовых данных - 62,78%. В связи с чем необходимо перенастроить модель, используя дополнительные параметры

# %%
def decisionTreeRegressorOptimizer(X_trn, X_tst, y_trn, y_tst, max_depth):
  for i in range(max_depth):
        model = DecisionTreeRegressor(random_state=20, max_depth=(i + 1))
        model.fit(X_trn, y_trn)

        housing_dt_predictions = model.predict(X_tst)
        tree_mse = mse(y_tst, housing_dt_predictions)
        tree_rmse = np.sqrt(tree_mse)

        train_score = model.score(X_trn, y_trn)
        test_score = model.score(X_tst, y_tst)

        print(f'max_depth: {i+1}')
        print('Предсказанные значения: ', housing_dt_predictions)
        print('Средняя квадратическая ошибка: ', tree_mse)
        print('Корень средней квадратической ошибки: ', tree_rmse)
        print('Точность модели на тренировочной выборке: ', train_score)
        print('Точность модели на тестовой выборке: ', test_score)
        print('----------------------------------------------------------')

def decisionTreeRegressorOptimizer_samples_leaf(X_trn, X_tst, y_trn, y_tst, min_samples_leaf):
  for i in range(min_samples_leaf):
        model = DecisionTreeRegressor(random_state=20, max_depth=9, min_samples_leaf=(i+1))
        model.fit(X_trn, y_trn)

        housing_dt_predictions = model.predict(X_tst)
        tree_mse = mse(y_tst, housing_dt_predictions)
        tree_rmse = np.sqrt(tree_mse)

        train_score = model.score(X_trn, y_trn)
        test_score = model.score(X_tst, y_tst)

        print(f'min_samples_leaf: {i+1}')
        print('Предсказанные значения: ', housing_dt_predictions)
        print('Средняя квадратическая ошибка: ', tree_mse)
        print('Корень средней квадратической ошибки: ', tree_rmse)
        print('Точность модели на тренировочной выборке: ', train_score)
        print('Точность модели на тестовой выборке: ', test_score)
        print('----------------------------------------------------------')

# %%
decisionTreeRegressorOptimizer(X_train, X_test, y_train, y_test, 25)
# Out:
# max_depth: 1
# Предсказанные значения:  [1.73858948 3.29137813 1.73858948 ... 1.73858948 3.29137813 1.73858948]
# Средняя квадратическая ошибка:  0.942802843944017
# Корень средней квадратической ошибки:  0.9709803519865976
# Точность модели на тренировочной выборке:  0.3061759759814944
# Точность модели на тестовой выборке:  0.32412612400959817
# ----------------------------------------------------------
# max_depth: 2
# Предсказанные значения:  [1.37617238 2.91163646 1.37617238 ... 2.10487101 2.91163646 1.37617238]
# Средняя квадратическая ошибка:  0.750560031089045
# Корень средней квадратической ошибки:  0.8663486775479288
# Точность модели на тренировочной выборке:  0.4429923774953122
# Точность модели на тестовой выборке:  0.4619406160746037
# ----------------------------------------------------------
# max_depth: 3
# Предсказанные значения:  [1.71612869 2.65104074 1.22315435 ... 1.90224783 2.65104074 1.71612869]
# Средняя квадратическая ошибка:  0.6407556111093196
# Корень средней квадратической ошибки:  0.800472117633912
# Точность модели на тренировочной выборке:  0.5298215018796514
# Точность модели на тестовой выборке:  0.5406569027397103
# ----------------------------------------------------------
# max_depth: 4
# Предсказанные значения:  [2.02009718 2.94424005 0.97318202 ... 2.12144788 2.37548473 1.47547579]
# Средняя квадратическая ошибка:  0.5731557081171067
# Корень средней квадратической ошибки:  0.7570704776420136
# Точность модели на тренировочной выборке:  0.5840633799300674
# Точность модели на тестовой выборке:  0.5891177328542989
# ----------------------------------------------------------
# max_depth: 5
# Предсказанные значения:  [1.73285884 2.7759569  0.86320698 ... 2.38645885 2.21683131 1.25231923]
# Средняя квадратическая ошибка:  0.5196103260776119
# Корень средней квадратической ошибки:  0.7208400142039924
# Точность модели на тренировочной выборке:  0.6308794572186776
# Точность модели на тестовой выборке:  0.6275031971460986
# ----------------------------------------------------------
# max_depth: 6
# Предсказанные значения:  [1.54577866 2.62821169 0.96822533 ... 2.49902304 2.20054027 1.19712832]
# Средняя квадратическая ошибка:  0.4872504640355142
# Корень средней квадратической ошибки:  0.6980332828995436
# Точность модели на тренировочной выборке:  0.6666326190511231
# Точность модели на тестовой выборке:  0.650701244887887
# ----------------------------------------------------------
# max_depth: 7
# Предсказанные значения:  [1.5371746  2.45573743 1.23294091 ... 2.40382817 2.30377835 1.32574482]
# Средняя квадратическая ошибка:  0.45393942940170084
# Корень средней квадратической ошибки:  0.6737502722832109
# Точность модели на тренировочной выборке:  0.7073223512390443
# Точность модели на тестовой выборке:  0.6745811665871292
# ----------------------------------------------------------
# max_depth: 8
# Предсказанные значения:  [1.56156667 2.20924    1.80271429 ... 2.51200889 2.35934847 1.0431867 ]
# Средняя квадратическая ошибка:  0.43421407750709134
# Корень средней квадратической ошибки:  0.6589492222524368
# Точность модели на тренировочной выборке:  0.748286902179589
# Точность модели на тестовой выборке:  0.6887218218958397
# ----------------------------------------------------------
# max_depth: 9
# Предсказанные значения:  [1.51017582 2.24627083 1.58473077 ... 2.26960451 2.32211621 0.93997247]
# Средняя квадратическая ошибка:  0.4348846940442092
# Корень средней квадратической ошибки:  0.6594578789006992
# Точность модели на тренировочной выборке:  0.7880954522006867
# Точность модели на тестовой выборке:  0.688241072181139
# ----------------------------------------------------------
# max_depth: 10
# Предсказанные значения:  [1.57862037 2.3177619  1.5024     ... 1.3836     2.28784262 0.6850796 ]
# Средняя квадратическая ошибка:  0.429624330055598
# Корень средней квадратической ошибки:  0.6554573441922807
# Точность модели на тренировочной выборке:  0.8288158591074422
# Точность модели на тестовой выборке:  0.6920121072612093
# ----------------------------------------------------------
# max_depth: 11
# Предсказанные значения:  [1.56107547 2.266275   1.63244444 ... 1.21764286 2.33566909 0.75385   ]
# Средняя квадратическая ошибка:  0.43424254142113283
# Корень средней квадратической ошибки:  0.6589708198555781
# Точность модели на тренировочной выборке:  0.8666219243850306
# Точность модели на тестовой выборке:  0.688701416764446
# ----------------------------------------------------------
# max_depth: 12
# Предсказанные значения:  [1.54971154 2.29617949 1.715      ... 1.06765    2.43283929 0.77257895]
# Средняя квадратическая ошибка:  0.4426146363645801
# Корень средней квадратической ошибки:  0.665292895170676
# Точность модели на тренировочной выборке:  0.8992256191930412
# Точность модели на тестовой выборке:  0.6826996526671758
# ----------------------------------------------------------
# max_depth: 13
# Предсказанные значения:  [1.6110597  2.32023684 1.5946     ... 1.122      2.40845455 0.8898    ]
# Средняя квадратическая ошибка:  0.46747766065057245
# Корень средней квадратической ошибки:  0.6837233802134987
# Точность модели на тренировочной выборке:  0.9257055429597469
# Точность модели на тестовой выборке:  0.6648759170887807
# ----------------------------------------------------------
# max_depth: 14
# Предсказанные значения:  [1.59012698 2.36806061 1.64522222 ... 1.29975    2.49647664 0.82466667]
# Средняя квадратическая ошибка:  0.47107713800080414
# Корень средней квадратической ошибки:  0.6863505940849793
# Точность модели на тренировочной выборке:  0.9468964103701629
# Точность модели на тестовой выборке:  0.6622955337945771
# ----------------------------------------------------------
# max_depth: 15
# Предсказанные значения:  [1.322      2.44691304 1.688      ... 1.1485     2.60177632 0.859     ]
# Средняя квадратическая ошибка:  0.4831082803124647
# Корень средней квадратической ошибки:  0.6950599113115824
# Точность модели на тренировочной выборке:  0.9627264914025054
# Точность модели на тестовой выборке:  0.6536706820145829
# ----------------------------------------------------------
# max_depth: 16
# Предсказанные значения:  [1.531      2.73642857 1.6162     ... 1.234      1.6395     0.859     ]
# Средняя квадратическая ошибка:  0.4803530881454864
# Корень средней квадратической ошибки:  0.6930750956032733
# Точность модели на тренировочной выборке:  0.9747809121027573
# Точность модели на тестовой выборке:  0.6556458164989085
# ----------------------------------------------------------
# max_depth: 17
# Предсказанные значения:  [1.142      2.65083333 1.55166667 ... 1.063      1.193      0.823     ]
# Средняя квадратическая ошибка:  0.5146658853414133
# Корень средней квадратической ошибки:  0.7174021782385479
# Точность модели на тренировочной выборке:  0.9838061900001309
# Точность модели на тестовой выборке:  0.6310477540451842
# ----------------------------------------------------------
# max_depth: 18
# Предсказанные значения:  [1.142 2.609 1.531 ... 1.397 2.086 0.859]
# Средняя квадратическая ошибка:  0.5092603504104848
# Корень средней квадратической ошибки:  0.7136247966617225
# Точность модели на тренировочной выборке:  0.9898495889223153
# Точность модели на тестовой выборке:  0.6349228588659173
# ----------------------------------------------------------
# max_depth: 19
# Предсказанные значения:  [1.142   2.63275 1.569   ... 1.063   1.193   0.859  ]
# Средняя квадратическая ошибка:  0.5151329862739686
# Корень средней квадратической ошибки:  0.7177276546671227
# Точность модели на тренировочной выборке:  0.9938554685287667
# Точность модели на тестовой выборке:  0.6307129000300604
# ----------------------------------------------------------
# max_depth: 20
# Предсказанные значения:  [1.293 2.514 1.531 ... 1.063 1.193 0.859]
# Средняя квадратическая ошибка:  0.5046217784155159
# Корень средней квадратической ошибки:  0.7103673545536252
# Точность модели на тренировочной выборке:  0.9964455052575133
# Точность модели на тестовой выборке:  0.6382481454339819
# ----------------------------------------------------------
# max_depth: 21
# Предсказанные значения:  [1.142  2.6315 1.555  ... 1.397  1.193  0.859 ]
# Средняя квадратическая ошибка:  0.518900425399661
# Корень средней квадратической ошибки:  0.7203474338120883
# Точность модели на тренировочной выборке:  0.9981563247949623
# Точность модели на тестовой выборке:  0.6280121087662287
# ----------------------------------------------------------
# max_depth: 22
# Предсказанные значения:  [1.142 2.605 1.569 ... 1.505 1.193 0.859]
# Средняя квадратическая ошибка:  0.5276411284684067
# Корень средней квадратической ошибки:  0.7263891026635839
# Точность модели на тренировочной выборке:  0.999123513715476
# Точность модели на тестовой выборке:  0.6217460979030869
# ----------------------------------------------------------
# max_depth: 23
# Предсказанные значения:  [1.142 2.605 1.569 ... 1.063 2.086 0.792]
# Средняя квадратическая ошибка:  0.5314893794331766
# Корень средней квадратической ошибки:  0.7290331812977902
# Точность модели на тренировочной выборке:  0.9995859882302742
# Точность модели на тестовой выборке:  0.61898737447321
# ----------------------------------------------------------
# max_depth: 24
# Предсказанные значения:  [1.142 2.514 1.569 ... 1.063 1.193 0.823]
# Средняя квадратическая ошибка:  0.5270553052915409
# Корень средней квадратической ошибки:  0.7259857473060617
# Точность модели на тренировочной выборке:  0.9998147397241479
# Точность модели на тестовой выборке:  0.6221660611899358
# ----------------------------------------------------------
# max_depth: 25
# Предсказанные значения:  [1.142 2.514 1.569 ... 1.063 1.193 0.859]
# Средняя квадратическая ошибка:  0.499823769759163
# Корень средней квадратической ошибки:  0.7069821566059238
# Точность модели на тренировочной выборке:  0.999919456897167
# Точность модели на тестовой выборке:  0.6416877285116473
# ----------------------------------------------------------

# %% [markdown]
# Наилучший компромисс между точностью на тренировочной и тестовой выборках определяется при значении параметра max_depth = 9 (78% и 70% соответственно)

# %%
decisionTreeRegressorOptimizer_samples_leaf(X_train, X_test, y_train, y_test, 25)
# Out:
# min_samples_leaf: 1
# Предсказанные значения:  [1.51017582 2.24627083 1.58473077 ... 2.26960451 2.32211621 0.93997247]
# Средняя квадратическая ошибка:  0.4348846940442092
# Корень средней квадратической ошибки:  0.6594578789006992
# Точность модели на тренировочной выборке:  0.7880954522006867
# Точность модели на тестовой выборке:  0.688241072181139
# ----------------------------------------------------------
# min_samples_leaf: 2
# Предсказанные значения:  [1.61745714 2.24627083 1.58473077 ... 2.26960451 2.32211621 0.93997247]
# Средняя квадратическая ошибка:  0.4276333696281718
# Корень средней квадратической ошибки:  0.6539368238814601
# Точность модели на тренировочной выборке:  0.7886109596387327
# Точность модели на тестовой выборке:  0.6934393814253378
# ----------------------------------------------------------
# min_samples_leaf: 3
# Предсказанные значения:  [1.61745714 2.27243182 1.58473077 ... 2.26960451 2.32211621 0.93997247]
# Средняя квадратическая ошибка:  0.42717943736151615
# Корень средней квадратической ошибки:  0.6535896551824517
# Точность модели на тренировочной выборке:  0.7868101900107721
# Точность модели на тестовой выборке:  0.6937647951239412
# ----------------------------------------------------------
# min_samples_leaf: 4
# Предсказанные значения:  [1.61745714 2.27243182 1.58473077 ... 2.26960451 2.32211621 0.93997247]
# Средняя квадратическая ошибка:  0.4169553630034822
# Корень средней квадратической ошибки:  0.645720808866713
# Точность модели на тренировочной выборке:  0.7850223131105354
# Точность модели на тестовой выборке:  0.7010942010640752
# ----------------------------------------------------------
# min_samples_leaf: 5
# Предсказанные значения:  [1.61745714 2.27243182 1.58473077 ... 2.26960451 2.36469125 0.93997247]
# Средняя квадратическая ошибка:  0.40074575125801704
# Корень средней квадратической ошибки:  0.6330448256308687
# Точность модели на тренировочной выборке:  0.7814582867742373
# Точность модели на тестовой выборке:  0.7127145023699945
# ----------------------------------------------------------
# min_samples_leaf: 6
# Предсказанные значения:  [1.61745714 2.27243182 1.58473077 ... 2.26960451 2.36469125 0.93997247]
# Средняя квадратическая ошибка:  0.39704760204560685
# Корень средней квадратической ошибки:  0.6301171335915307
# Точность модели на тренировочной выборке:  0.7798576388553241
# Точность модели на тестовой выборке:  0.7153656212738433
# ----------------------------------------------------------
# min_samples_leaf: 7
# Предсказанные значения:  [1.61745714 2.2837619  1.58473077 ... 2.26960451 2.36469125 0.93997247]
# Средняя квадратическая ошибка:  0.3995105565517734
# Корень средней квадратической ошибки:  0.6320684745751629
# Точность модели на тренировочной выборке:  0.7782546890663632
# Точность модели на тестовой выборке:  0.7135999853095869
# ----------------------------------------------------------
# min_samples_leaf: 8
# Предсказанные значения:  [1.61745714 2.2837619  1.58473077 ... 2.26960451 2.36469125 0.93997247]
# Средняя квадратическая ошибка:  0.39961948475604625
# Корень средней квадратической ошибки:  0.6321546367432942
# Точность модели на тренировочной выборке:  0.7765497710325336
# Точность модели на тестовой выборке:  0.7135218971619965
# ----------------------------------------------------------
# min_samples_leaf: 9
# Предсказанные значения:  [1.61745714 2.33675    1.58473077 ... 2.26960451 2.36469125 0.93997247]
# Средняя квадратическая ошибка:  0.39999238062002457
# Корень средней квадратической ошибки:  0.6324495083562202
# Точность модели на тренировочной выборке:  0.7747550508443044
# Точность модели на тестовой выборке:  0.713254576613966
# ----------------------------------------------------------
# min_samples_leaf: 10
# Предсказанные значения:  [1.61745714 2.33675    2.0244     ... 2.26960451 2.36568753 0.93997247]
# Средняя квадратическая ошибка:  0.40023822534604403
# Корень средней квадратической ошибки:  0.6326438376733342
# Точность модели на тренировочной выборке:  0.7729694762163617
# Точность модели на тестовой выборке:  0.7130783361317339
# ----------------------------------------------------------
# min_samples_leaf: 11
# Предсказанные значения:  [1.61745714 2.33675    2.032      ... 2.26960451 2.34507906 0.93997247]
# Средняя квадратическая ошибка:  0.3984438913357481
# Корень средней квадратической ошибки:  0.6312241213196372
# Точность модели на тренировочной выборке:  0.7705607533211307
# Точность модели на тестовой выборке:  0.7143646532977777
# ----------------------------------------------------------
# min_samples_leaf: 12
# Предсказанные значения:  [1.61745714 2.33675    2.04608696 ... 2.26960451 2.34507906 0.93997247]
# Средняя квадратическая ошибка:  0.404007552308062
# Корень средней квадратической ошибки:  0.6356158842477602
# Точность модели на тренировочной выборке:  0.7684636078884182
# Точность модели на тестовой выборке:  0.7103761915210569
# ----------------------------------------------------------
# min_samples_leaf: 13
# Предсказанные значения:  [1.67070588 2.33675    1.98       ... 2.26960451 2.34507906 0.93997247]
# Средняя квадратическая ошибка:  0.4048138527166404
# Корень средней квадратической ошибки:  0.636249835140757
# Точность модели на тренировочной выборке:  0.7677143622266652
# Точность модели на тестовой выборке:  0.7097981731306171
# ----------------------------------------------------------
# min_samples_leaf: 14
# Предсказанные значения:  [1.6694881  2.33675    1.98561905 ... 2.26960451 2.34507906 0.93997247]
# Средняя квадратическая ошибка:  0.40239068273716255
# Корень средней квадратической ошибки:  0.6343427170994892
# Точность модели на тренировочной выборке:  0.7656629776479875
# Точность модели на тестовой выборке:  0.7115352884742261
# ----------------------------------------------------------
# min_samples_leaf: 15
# Предсказанные значения:  [1.58523077 2.33675    1.99375    ... 2.26960451 2.34507906 0.93997247]
# Средняя квадратическая ошибка:  0.40464627561066097
# Корень средней квадратической ошибки:  0.636118130232633
# Точность модели на тренировочной выборке:  0.7642435877527858
# Точность модели на тестовой выборке:  0.7099183053394593
# ----------------------------------------------------------
# min_samples_leaf: 16
# Предсказанные значения:  [1.58523077 2.33675    1.5828125  ... 2.26960451 2.34507906 0.93997247]
# Средняя квадратическая ошибка:  0.40300983843170063
# Корень средней квадратической ошибки:  0.6348305588357421
# Точность модели на тренировочной выборке:  0.7634530266207321
# Точность модели на тестовой выборке:  0.7110914298649771
# ----------------------------------------------------------
# min_samples_leaf: 17
# Предсказанные значения:  [1.58523077 2.33675    1.66147059 ... 2.26960451 2.34507906 0.93997247]
# Средняя квадратическая ошибка:  0.4003312696401238
# Корень средней квадратической ошибки:  0.6327173694787617
# Точность модели на тренировочной выборке:  0.7614235190572693
# Точность модели на тестовой выборке:  0.7130116347974279
# ----------------------------------------------------------
# min_samples_leaf: 18
# Предсказанные значения:  [1.58661765 2.33675    1.80271429 ... 2.26960451 2.34507906 0.93997247]
# Средняя квадратическая ошибка:  0.40156224790220124
# Корень средней квадратической ошибки:  0.6336893938691109
# Точность модели на тренировочной выборке:  0.7607166548825504
# Точность модели на тестовой выборке:  0.7121291745305818
# ----------------------------------------------------------
# min_samples_leaf: 19
# Предсказанные значения:  [1.58661765 2.32732258 1.80271429 ... 2.26960451 2.34507906 0.93777764]
# Средняя квадратическая ошибка:  0.40043418411280784
# Корень средней квадратической ошибки:  0.6327986916174905
# Точность модели на тренировочной выборке:  0.7596812046076158
# Точность модели на тестовой выборке:  0.7129378577569838
# ----------------------------------------------------------
# min_samples_leaf: 20
# Предсказанные значения:  [1.58661765 2.36616667 1.80271429 ... 2.26960451 2.34507906 0.74035679]
# Средняя квадратическая ошибка:  0.39958204860851715
# Корень средней квадратической ошибки:  0.632125026089394
# Точность модели на тренировочной выборке:  0.7576383152780921
# Точность модели на тестовой выборке:  0.713548734283135
# ----------------------------------------------------------
# min_samples_leaf: 21
# Предсказанные значения:  [1.6936     2.36616667 1.80271429 ... 2.26960451 2.34507906 0.74035679]
# Средняя квадратическая ошибка:  0.4017826803751963
# Корень средней квадратической ошибки:  0.6338632978609791
# Точность модели на тренировочной выборке:  0.7556543838414155
# Точность модели на тестовой выборке:  0.7119711515134957
# ----------------------------------------------------------
# min_samples_leaf: 22
# Предсказанные значения:  [1.6936     2.36616667 1.80271429 ... 2.26960451 2.34507906 0.74035679]
# Средняя квадратическая ошибка:  0.40234524231550584
# Корень средней квадратической ошибки:  0.634306899154901
# Точность модели на тренировочной выборке:  0.7549981200804095
# Точность модели на тестовой выборке:  0.7115678636771002
# ----------------------------------------------------------
# min_samples_leaf: 23
# Предсказанные значения:  [1.5104186  2.36616667 1.80271429 ... 2.26960451 2.34507906 0.74035679]
# Средняя квадратическая ошибка:  0.4010211026546007
# Корень средней квадратической ошибки:  0.6332622700387263
# Точность модели на тренировочной выборке:  0.7538330451972537
# Точность модели на тестовой выборке:  0.7125171092279777
# ----------------------------------------------------------
# min_samples_leaf: 24
# Предсказанные значения:  [1.5104186  2.36616667 1.80271429 ... 2.26960451 2.34507906 0.74035679]
# Средняя квадратическая ошибка:  0.4020744251122358
# Корень средней квадратической ошибки:  0.6340933883208654
# Точность модели на тренировочной выборке:  0.7528524505000448
# Точность модели на тестовой выборке:  0.7117620063592471
# ----------------------------------------------------------
# min_samples_leaf: 25
# Предсказанные значения:  [1.5104186  2.35092    1.80271429 ... 2.26960451 2.34507906 0.74035679]
# Средняя квадратическая ошибка:  0.40479971753072624
# Корень средней квадратической ошибки:  0.6362387268397973
# Точность модели на тренировочной выборке:  0.7514967339279766
# Точность модели на тестовой выборке:  0.7098083063233127
# ----------------------------------------------------------

# %% [markdown]
# Наилучший компромисс между точностью на тренировочной и тестовой выборках определяется при значении параметра min_samples_leaf = 10 (77,1% и 71,89% соответственно)

# %% [markdown]
# Сформулируйте выводы по проделанной работе.
#
# a. Сравните точность двух моделей.
#
# b. Напишите свое мнение, для каких задач предпочтительнее использовать обученные в работе модели? Какие у них есть плюсы и минусы?
#
# Для получения зачета по этому домашнему заданию, должно быть как минимум реализовано обучение двух моделей, выведена их точность, оптимизирован один параметр дерева решений.

# %% [markdown]
# Выводы:
#
# а) Модель DecisionTreeRegressor показывает более высокую точность предсказания по сравнению с моделью линейной регрессии. Однако DecisionTreeRegressor склонна к переобучению, поэтому во избежание последнего необходимо подбирать оптимальные параметры модели
#
# b) Модель на основе линейной регрессии отличается простотой и может быть использована в случаях, где наблюдается сильная корреляция / линейная взаимосвязь между признаками и целевой переменной; DecisionTreeRegressor является более сложной и ресурсозатратной моделью, но она может показать более высокую точность предсказания в случаях отсутствия явных корреляционных взаимоотношений между признаками и целевой переменной.
